# %% [markdown]
# #                                                         👾 FUNDAMENTAL BOOSTER 👾

# %%
print("Welcome to the Interactive Personal Data Collector!")
print("              ")
name = str(input("Please enter your name:"))
age = int(input("Please enter your age:"))
height = float(input("Please enter your height in meters:"))
num = int(input("Please enter your favourite number:"))
print("              ")
print("Thank you! Here is the information we collected:")
print("              ")
print("Name:", name, "(Type:",type(name), ", ", "Memory address:", id(name),")")
print("Age:", age, "(Type:",type(name), ", ", "Memory address:", id(name),")")
print("Height:", height, "(Type:",type(name), ", ", "Memory address:", id(name),")")
print("Favourite number:", num, "(Type:",type(name), ", ", "Memory address:", id(name),")")
print("              ")
birth_year = 2026 - age
print("Your birth year is approximately:", birth_year,"(based on your age", age, ")")
print("              ")
print("Thank you for using the Personal Data Collector, Goodbye!")
# Out:
# Welcome to the Interactive Personal Data Collector!
# Please enter your name: Vidhi Darji
# Please enter your age: 19
# Please enter your height in meters: 1.65
# Please enter your favourite number: 11
#
# Thank you! Here is the information we collected:
#
# Name: Vidhi Darji (Type: <class 'str'> ,  Memory address: 2773880585520 )
# Age: 19 (Type: <class 'str'> ,  Memory address: 2773880585520 )
# Height: 1.65 (Type: <class 'str'> ,  Memory address: 2773880585520 )
# Favourite number: 11 (Type: <class 'str'> ,  Memory address: 2773880585520 )
#
# Your birth year is approximately: 2007 (based on your age 19 )
#
# Thank you for using the Personal Data Collector, Goodbye!
